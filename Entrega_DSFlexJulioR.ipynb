# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeJohnWick94/ProjectDS1/blob/main/Entrega_DSFlexJulioR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Patrones de carga de vehículos eléctricos
# En este caso se busca determinar si la marca Chevrolet es la que más veces carga sus baterías en menos tiempo que el resto de las marcas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url="https://raw.github.com/CodeJohnWick94/ProjectDS1/master/ev_charging_patterns.csv"
df=pd.read_csv(url, sep=",", header=None)
df.head()
# Out:
#         0              1                       2                    3   \
# 0  User ID  Vehicle Model  Battery Capacity (kWh)  Charging Station ID
# 1   User_1         BMW i3      108.46300741284072          Station_391
# 2   User_2   Hyundai Kona                   100.0          Station_428
# 3   User_3     Chevy Bolt                    75.0          Station_181
# 4   User_4   Hyundai Kona                    50.0          Station_327
#
#                           4                    5                    6   \
# 0  Charging Station Location  Charging Start Time    Charging End Time
# 1                    Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# 2              San Francisco  2024-01-01 01:00:00  2024-01-01 03:01:00
# 3              San Francisco  2024-01-01 02:00:00  2024-01-01 04:48:00
# 4                    Houston  2024-01-01 03:00:00  2024-01-01 06:42:00
#
#                       7                          8                   9   \
# ...

# %%
df = df.rename(columns={0: "USER ID", 1: "VEHICLE MODEL", 2: "BATTERY CAPACITY (kwh)", 3: "ID CHARGING STATION", 4: "LOCATION OF STATION",
                       5: "START TIME CHARG", 6: "END TIME CHARG", 7: "ENERGY CONSUMED (kWh)", 8: "CHARGING DURATION", 9: "CHARGING RATE (kWh)",
                       10: "CHARGING COST", 11: "TIME OF DAY", 12: "DAY OF WEEK", 13: "START CHARGE %", 14: "END CHARGE %", 15: "DISTANCE DRIVEN SINCE LAST CHARGE (KM)",
                       16: "TEMPERATURE C", 17: "VEHICLE YEARS", 18: "CHARGE TYPE", 19: "USER TYPE"})
df.head()
# Out:
#    USER ID  VEHICLE MODEL  BATTERY CAPACITY (kwh)  ID CHARGING STATION  \
# 0  User ID  Vehicle Model  Battery Capacity (kWh)  Charging Station ID
# 1   User_1         BMW i3      108.46300741284072          Station_391
# 2   User_2   Hyundai Kona                   100.0          Station_428
# 3   User_3     Chevy Bolt                    75.0          Station_181
# 4   User_4   Hyundai Kona                    50.0          Station_327
#
#          LOCATION OF STATION     START TIME CHARG       END TIME CHARG  \
# 0  Charging Station Location  Charging Start Time    Charging End Time
# 1                    Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# 2              San Francisco  2024-01-01 01:00:00  2024-01-01 03:01:00
# 3              San Francisco  2024-01-01 02:00:00  2024-01-01 04:48:00
# 4                    Houston  2024-01-01 03:00:00  2024-01-01 06:42:00
#
#    ENERGY CONSUMED (kWh)          CHARGING DURATION CHARGING RATE (kWh)  \
# ...
